# %% [markdown]
# <a href="https://colab.research.google.com/github/DarkGengar/DataScienceJourney/blob/master/Sentimental_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 3.7MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
# Add your own keys of Twitter App
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
tweets = api.search('Artificial Intelligence', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
display(data.head(10))

print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  Can we take a moment to say holly shit we live...
# 1  RT @david_green_uk: IBM artificial intelligenc...
# 2  RT @IainLJBrown: How artificial intelligence c...
# 3  RT @TheTweetOfGod: Artificial intelligence isn...
# 4  RT @TheTweetOfGod: Artificial intelligence isn...
# 5               RT @NAajtak: https://t.co/NWp67pDKfu
# 6  RT @TheTweetOfGod: Artificial intelligence isn...
# 7  Artificial Intelligence is expected to play a ...
# 8  RT @CelineDarnet_: Artificial Intelligence is ...
# 9       RT @Lovebea92974295: https://t.co/rEJD6FcEjB
# 2019-04-10 06:26:57

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()

listy = []

for index, row in data.iterrows():
    ss = sid.polarity_scores(row["Tweets"])
    listy.append(ss)
    
se = pd.Series(listy)
data['polarity'] = se.values
display(data.head(100))
# Out:
#                                                Tweets  \
# 0   Can we take a moment to say holly shit we live...
# 1   RT @david_green_uk: IBM artificial intelligenc...
# 2   RT @IainLJBrown: How artificial intelligence c...
# 3   RT @TheTweetOfGod: Artificial intelligence isn...
# 4   RT @TheTweetOfGod: Artificial intelligence isn...
# 5                RT @NAajtak: https://t.co/NWp67pDKfu
# 6   RT @TheTweetOfGod: Artificial intelligence isn...
# 7   Artificial Intelligence is expected to play a ...
# 8   RT @CelineDarnet_: Artificial Intelligence is ...
# 9        RT @Lovebea92974295: https://t.co/rEJD6FcEjB
# 10  RT @TheTweetOfGod: Artificial intelligence isn...
# 11  RT @TheTweetOfGod: Artificial intelligence isn...
# 12  RT @TheTweetOfGod: Artificial intelligence isn...
# 13  RT @TheTweetOfGod: Artificial intelligence isn...
# 14  RT @TheTweetOfGod: Artificial intelligence isn...
# 15  RT @EU_Commission: We work towards a sustainab...
# ...
